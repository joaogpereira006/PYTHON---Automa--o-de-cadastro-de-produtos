# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


tabela = pd.read_excel('Efetivação de cargas.xlsx')

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))

ax = sns.countplot(data=tabela, x='Efetiv.', palette='magma')

total = len(df['Efetiv.'])
for p in ax.patches:

    percentage = '{:.1f}%'.format(100 * p.get_height()/total)


    x = p.get_x() + p.get_width() / 2
    y = p.get_height() + 0.5


    ax.annotate(percentage, (x, y), ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.title('Percentual de Efetivação de Cargas', fontsize=15)
plt.ylabel('Quantidade de Cargas')
plt.show()
# Out:
# /tmp/ipython-input-2575912309.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=tabela, x='Efetiv.', palette='magma')
